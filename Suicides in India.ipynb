# %% [markdown]
# Analysis of Suicides in India

# %% [markdown]
# 'Mental pain is less dramatic than physical pain, but it is more common and also harder to bear
#    -C.S Lewis

# %% [markdown]
# Description:

# %% [markdown]
# According to the recent report of WHO, India is the 6th most depressed country in the world.This project uses explanatory analysis of the Suicide rate in India from 2001-2012 data to understand the causes and circumstances behind these rising suicide numbers.

# %% [markdown]
# About the dataset
# This dataset contains yearly suicide details of all states/u.t of India by various parameters from 2001-2012.
# Parameters:
#
# a) Suicide causes
# b) Education status
# c) By means adopted
# d) Professional profile
# e) Social status
#
# The data was taken from National Crime Records Bureau (NCRB), Govt of India.

# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
import plotly as py
import plotly.graph_objs as go
import plotly.express as px
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv('C:/Users/ankur/Documents/Ankur/Python Suicides in India project/Suicides in India 2001-2012.csv')

# %%
df.head()
# Out:
#            State  Year Type_code                                     Type  \
# 0  A & N Islands  2001    Causes                       Illness (Aids/STD)
# 1  A & N Islands  2001    Causes  Bankruptcy or Sudden change in Economic
# 2  A & N Islands  2001    Causes  Cancellation/Non-Settlement of Marriage
# 3  A & N Islands  2001    Causes        Physical Abuse (Rape/Incest Etc.)
# 4  A & N Islands  2001    Causes                            Dowry Dispute
#
#    Gender Age_group  Total
# 0  Female      0-14      0
# 1  Female      0-14      0
# 2  Female      0-14      0
# 3  Female      0-14      0
# 4  Female      0-14      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237519 entries, 0 to 237518
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   State      237519 non-null  object
#  1   Year       237519 non-null  int64
#  2   Type_code  237519 non-null  object
#  3   Type       237519 non-null  object
#  4   Gender     237519 non-null  object
#  5   Age_group  237519 non-null  object
#  6   Total      237519 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 12.7+ MB

# %%
df.duplicated().any()
# Out:
# False

# %%
df.sample(10)
# Out:
#                   State  Year             Type_code  \
# 67410        Delhi (Ut)  2012  Professional_Profile
# 3176      A & N Islands  2006         Means_adopted
# 227525      Uttarakhand  2007                Causes
# 224152      Uttarakhand  2001                Causes
# 100398  Jammu & Kashmir  2011                Causes
# 151820        Meghalaya  2006         Means_adopted
# 103165        Jharkhand  2004                Causes
# 229777      Uttarakhand  2011                Causes
# 74061               Goa  2012         Means_adopted
# 73564               Goa  2011  Professional_Profile
#
#                                            Type  Gender Age_group  Total
# 67410                            Retired Person  Female     30-44      0
# 3176    By coming under running vehicles/trains  Female     45-59      0
# 227525                            Dowry Dispute  Female     45-59      0
# 224152                         Property Dispute  Female     45-59      0
# 100398                            Dowry Dispute  Female     45-59      0
# 151820                             By Fire-Arms    Male     15-29      0
# 103165                                  Divorce  Female     30-44      1
# 229777                Fall in Social Reputation  Female     45-59      0
# 74061                              By Fire-Arms  Female     45-59      0
# 73564                 Public Sector Undertaking  Female      0-14      0

# %%
df.Type_code.value_counts()
# Out:
# Causes                  109200
# Means_adopted            67200
# Professional_Profile     49263
# Education_Status          7296
# Social_Status             4560
# Name: Type_code, dtype: int64

# %%
len(df[df['Total']==0])
# Out:
# 135481

# %%
df.State.value_counts()
# Out:
# Madhya Pradesh       6792
# Maharashtra          6792
# Karnataka            6792
# Odisha               6791
# Andhra Pradesh       6791
# Rajasthan            6791
# Bihar                6790
# Chhattisgarh         6790
# Haryana              6790
# Kerala               6788
# Uttar Pradesh        6787
# Assam                6786
# Tamil Nadu           6786
# Gujarat              6786
# Jharkhand            6785
# Tripura              6782
# Delhi (Ut)           6782
# West Bengal          6780
# Punjab               6779
# Himachal Pradesh     6774
# Jammu & Kashmir      6761
# Goa                  6759
# Uttarakhand          6758
# Sikkim               6742
# Mizoram              6737
# Meghalaya            6733
# Puducherry           6730
# Chandigarh           6717
# A & N Islands        6712
# Daman & Diu          6710
# Arunachal Pradesh    6707
# Nagaland             6705
# D & N Haveli         6704
# Manipur              6700
# Lakshadweep          6674
# Total (All India)     312
# Total (States)        312
# Total (Uts)           312
# Name: State, dtype: int64

# %%
df.Age_group.value_counts()
# Out:
# 15-29     45223
# 30-44     45193
# 45-59     45146
# 60+       45074
# 0-14      45027
# 0-100+    11856
# Name: Age_group, dtype: int64

# %% [markdown]
# Data Cleaning
#
# Before performing EDA the data must be cleaned like renaming some entries and dropping unnecessary rows.

# %%
# Rename States
df.replace('A & N Islands (Ut)','A & N Islands', inplace =True)
df.replace('Chandigarh (Ut)', 'Chandigarh', inplace=True)
df.replace('D & N Haveli (Ut)','D & N Haveli', inplace= True)
df.replace('Daman and Diu (Ut)','Daman and Diu', inplace=True)
df.replace('Lakshwadeep (Ut)', 'Lakshwadeep', inplace = True)
df.replace('Delhi (Ut)', 'Delhi', inplace= True)

# %%
# Rename Type
df.replace('Bankruptcy or Sudden change in Economic', 
           'Bankruptcy or Sudden change in Economic Status', inplace=True)
df.replace('By Other means (please specify)', 'By Other means', inplace=True)
df.replace('Not having Children(Barrenness/Impotency',
           'Not having Children (Barrenness/Impotency', inplace=True)

# %%
# Drop rows where total is zero
df=df.drop(df[df.Total==0].index)

# %%
df[df['Total']==0]
# Out:
# Empty DataFrame
# Columns: [State, Year, Type_code, Type, Gender, Age_group, Total]
# Index: []

# %%
df = df.drop(df[(df.State == 'Total (Uts)') | (df.State == 'Total (All India)') | 
               (df.State == 'Total (States)')].index)

# %% [markdown]
# Exploratory Data Analysis

# %%
# The below cell shows the most number of suicide counts in states,arranged in highest to lowest.

# %%
temp_state = df.groupby('State').count()['Total'].reset_index().sort_values(by='Total',ascending=False)
temp_state.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_4457f_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_4457f_row1_col1 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_4457f_row2_col1 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_4457f_row3_col1 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_4457f_row4_col1, #T_4457f_row5_col1 {
#   background-color: #7c0510;
#   color: #f1f1f1;
# }
# #T_4457f_row6_col1 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# #T_4457f_row7_col1 {
#   background-color: #9f0e14;
#   color: #f1f1f1;
# }
# #T_4457f_row8_col1 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_4457f_row9_col1 {
#   background-color: #af1117;
#   color: #f1f1f1;
# }
# #T_4457f_row10_col1 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# #T_4457f_row11_col1 {
#   background-color: #bb141a;
#   color: #f1f1f1;
# }
# #T_4457f_row12_col1 {
#   background-color: #cc191e;
#   color: #f1f1f1;
# }
# #T_4457f_row13_col1 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# #T_4457f_row14_col1 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_4457f_row15_col1 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_4457f_row16_col1 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_4457f_row17_col1 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_4457f_row18_col1 {
#   background-color: #fa6849;
#   color: #f1f1f1;
# }
# #T_4457f_row19_col1, #T_4457f_row20_col1 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_4457f_row21_col1 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_4457f_row22_col1 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_4457f_row23_col1 {
#   background-color: #fc8969;
#   color: #f1f1f1;
# }
# #T_4457f_row24_col1 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_4457f_row25_col1 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_4457f_row26_col1 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_4457f_row27_col1 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_4457f_row28_col1 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_4457f_row29_col1 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_4457f_row30_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_4457f_row31_col1 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_4457f_row32_col1, #T_4457f_row33_col1 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_4457f_row34_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_4457f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >State</th>
#       <th class="col_heading level0 col1" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4457f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4457f_row0_col0" class="data row0 col0" >Andhra Pradesh</td>
#       <td id="T_4457f_row0_col1" class="data row0 col1" >5185</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row1" class="row_heading level0 row1" >16</th>
#       <td id="T_4457f_row1_col0" class="data row1 col0" >Karnataka</td>
#       <td id="T_4457f_row1_col1" class="data row1 col1" >5115</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_4457f_row2_col0" class="data row2 col0" >Tamil Nadu</td>
#       <td id="T_4457f_row2_col1" class="data row2 col1" >5054</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row3" class="row_heading level0 row3" >19</th>
#       <td id="T_4457f_row3_col0" class="data row3 col0" >Madhya Pradesh</td>
#       <td id="T_4457f_row3_col1" class="data row3 col1" >5029</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row4" class="row_heading level0 row4" >20</th>
#       <td id="T_4457f_row4_col0" class="data row4 col0" >Maharashtra</td>
#       <td id="T_4457f_row4_col1" class="data row4 col1" >4958</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row5" class="row_heading level0 row5" >32</th>
#       <td id="T_4457f_row5_col0" class="data row5 col0" >Uttar Pradesh</td>
#       <td id="T_4457f_row5_col1" class="data row5 col1" >4954</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row6" class="row_heading level0 row6" >11</th>
#       <td id="T_4457f_row6_col0" class="data row6 col0" >Gujarat</td>
#       <td id="T_4457f_row6_col1" class="data row6 col1" >4856</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row7" class="row_heading level0 row7" >34</th>
#       <td id="T_4457f_row7_col0" class="data row7 col0" >West Bengal</td>
#       <td id="T_4457f_row7_col1" class="data row7 col1" >4596</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row8" class="row_heading level0 row8" >17</th>
#       <td id="T_4457f_row8_col0" class="data row8 col0" >Kerala</td>
#       <td id="T_4457f_row8_col1" class="data row8 col1" >4509</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row9" class="row_heading level0 row9" >6</th>
#       <td id="T_4457f_row9_col0" class="data row9 col0" >Chhattisgarh</td>
#       <td id="T_4457f_row9_col1" class="data row9 col1" >4368</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row10" class="row_heading level0 row10" >28</th>
#       <td id="T_4457f_row10_col0" class="data row10 col0" >Rajasthan</td>
#       <td id="T_4457f_row10_col1" class="data row10 col1" >4324</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row11" class="row_heading level0 row11" >25</th>
#       <td id="T_4457f_row11_col0" class="data row11 col0" >Odisha</td>
#       <td id="T_4457f_row11_col1" class="data row11 col1" >4179</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row12" class="row_heading level0 row12" >3</th>
#       <td id="T_4457f_row12_col0" class="data row12 col0" >Assam</td>
#       <td id="T_4457f_row12_col1" class="data row12 col1" >3868</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row13" class="row_heading level0 row13" >12</th>
#       <td id="T_4457f_row13_col0" class="data row13 col0" >Haryana</td>
#       <td id="T_4457f_row13_col1" class="data row13 col1" >3826</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row14" class="row_heading level0 row14" >9</th>
#       <td id="T_4457f_row14_col0" class="data row14 col0" >Delhi</td>
#       <td id="T_4457f_row14_col1" class="data row14 col1" >3324</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4457f_row15_col0" class="data row15 col0" >Jharkhand</td>
#       <td id="T_4457f_row15_col1" class="data row15 col1" >3210</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row16" class="row_heading level0 row16" >4</th>
#       <td id="T_4457f_row16_col0" class="data row16 col0" >Bihar</td>
#       <td id="T_4457f_row16_col1" class="data row16 col1" >3119</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row17" class="row_heading level0 row17" >27</th>
#       <td id="T_4457f_row17_col0" class="data row17 col0" >Punjab</td>
#       <td id="T_4457f_row17_col1" class="data row17 col1" >2960</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row18" class="row_heading level0 row18" >13</th>
#       <td id="T_4457f_row18_col0" class="data row18 col0" >Himachal Pradesh</td>
#       <td id="T_4457f_row18_col1" class="data row18 col1" >2650</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row19" class="row_heading level0 row19" >31</th>
#       <td id="T_4457f_row19_col0" class="data row19 col0" >Tripura</td>
#       <td id="T_4457f_row19_col1" class="data row19 col1" >2451</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row20" class="row_heading level0 row20" >33</th>
#       <td id="T_4457f_row20_col0" class="data row20 col0" >Uttarakhand</td>
#       <td id="T_4457f_row20_col1" class="data row20 col1" >2442</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row21" class="row_heading level0 row21" >10</th>
#       <td id="T_4457f_row21_col0" class="data row21 col0" >Goa</td>
#       <td id="T_4457f_row21_col1" class="data row21 col1" >2237</td>
#     </tr>
#     <tr>
#       <th id="T_4457f_level0_row22" class="row_heading level0 row22" >14</th>
#       <td id="T_4457f_row22_col0" class="data row22 col0" >Jammu & Kashmir</td>
#       <td id="T_4457f_row22_col1" clas

# %%
# Gender Suicide Frequency
counts = df['Gender'].value_counts().sort_index()
print(counts)
# Plot a pie chart
counts.plot(kind='pie', title='Gender Count',figsize=(10,8))

plt.legend()
plt.show()

# The pie chart shows that male are more prone to have suicidal instincts than female.
# Out:
# Female    46269
# Male      54841
# Name: Gender, dtype: int64

# %%
# Age Suicide Frequency
df_Age = df[df['Age_group']!='0-100+']

age = df_Age.groupby('Age_group').sum()['Total'].plot(kind="bar",figsize=(8,5), title ="Age wise suicides frequency");
age.set_xlabel('\nAge Group')
age.set_ylabel('Counts\n')
sns.set_style('whitegrid')
sns.set_palette('Set2');

# %%
# Suicide rate every year

year = df.groupby('Year').sum()['Total'].plot(kind='line', figsize=(6,6), title = 'Suicide rate per year');
year.set_xlabel('\nYear')
year.set_ylabel('Count\n')
sns.set_style('whitegrid');

# Suicide rate is sky rocketted from 2002 till almost 2010 but, it has droped from then.

# %%
# State wise Suicide count

state = df.groupby('State').sum()['Total']
sort_state = state.sort_values(ascending = False)
state_fig = sort_state.plot(kind='bar', figsize = (13,7), title = 'Suicide count across state\n', width = 0.75)
state_fig.set_xlabel('\nState')
state_fig.set_ylabel('Count\n')
sns.set_style('whitegrid')
sns.set_palette('Set2');

# Maharashtra, West Bengal and Tamil Nadu have the highest rate of suicide.

# %%
# split df ny it's type code

cause = df[df['Type_code'] == 'Causes']
edu_status = df[df['Type_code'] == 'Education_Status']
means_adpt = df[df['Type_code'] == 'Means_adopted']
prof = df[df['Type_code'] == 'Professional_Profile']
soc_status = df[df['Type_code'] == 'Social_Status']

# %%
# function to plot

def plot_type(df, Title, X_lab):
    p_type = df.groupby('Type').sum()['Total']
    sort_df = p_type.sort_values(ascending = False)

    fig = sort_df.plot(kind='bar', figsize = (15,6), title = Title + '\n', width = 0.75)
    fig.set_xlabel('\n' + X_lab )
    fig.set_ylabel('Count\n')
    sns.set_style('whitegrid')
    sns.set_palette('Set2');

# %%
# plot by cause
plot_type(cause, 'Suicide by cause', 'Cause')

# Most of the cause are unknown but Family problems and Prolonged illness is at the top.

# %%
# plot by education status
plot_type(edu_status, 'Suicide by Education Status', 'Education Status')

# People with primary or no education are high in number.

# %%
# plot by means adopted
plot_type(means_adpt, 'Suicide by Means Adopted', 'Means Adopted')

# %%
# suicide by profession
plot_type(prof, 'Suicide by Professional Profile', 'Professional Profile')

# %%
# suicide by social Status
plot_type(soc_status, 'Suicide by Social Status', 'Social Status',)

# %% [markdown]
# Family Problems, House Wife and now Married these are at the top when it comes to the cause, professional profile
# and social status respectively.

# %%
# Reason for kids suicide
age_lower = df[df['Age_group']== '0-14']
age_lower_cause = age_lower[age_lower['Type_code'] == 'Causes']
plot_type(age_lower_cause, 'Reason For Kids Suicide', 'Cause')

# Most of cause is unknown but, Failure in Examination is at the top.

# %%
# Reason for Middle age suicide
age_middle = df[df['Age_group']== '15-29']
age_middle_cause = age_middle[age_middle['Type_code'] == 'Causes']
plot_type(age_middle_cause, 'Reason For Middle Age Suicide', 'Cause')

# Family Problems, Illness and Love affairs are at the top while, most of the reasons are unknown yet.

# %% [markdown]
# Conclusion

# %% [markdown]
# Age group between 15-44 has the highest number of suicides.

# %% [markdown]
# Rate of suicide sky rocketed from 2002-2010 but since 2011 it has been decreasing but, since we have the data till 2012 we can't confim the pattern.

# %% [markdown]
# Maharashtra, West Bengal and Tamil Nadu have the highest suicide rate this might also be because of the high population in these states.

# %% [markdown]
# Family Problems, Illness, Mental Illness are some of the main reason while most of the reasons are still unknown.

# %% [markdown]
# Hanging, Consuming Insecticides is more common but, most of other means are unknown.

# %% [markdown]
# Most of the professional profile is unknown but house wife comes in second, while Farming comes in at third.

# %% [markdown]
# Married is at the top when it comes to social status while never married is at second.

# %% [markdown]
# The reason for suicide at the age group between 0-14 is because of Failure in Examination.

# %% [markdown]
# The reason for suicide at the age group between 15-29 is because of Family Problems.
